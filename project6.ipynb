# %% [markdown]
# FINAL PROJECT

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# DATA CLEANING

# %%
dataset = pd.read_csv("/Users/darren/Downloads/cvproject/dataset/dataset_final_project.csv")
dataset
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity       Date   Time  \
# 0         Health and beauty       74.69         7   1/5/2019  13:08
# 1    Electronic accessories       15.28         5   3/8/2019  10:29
# 2        Home and lifestyle       46.33         7   3/3/2019  13:23
# ...

# %%
dataset.dtypes
# Out:
# Invoice ID        object
# Branch            object
# City              object
# Customer type     object
# Gender            object
# Product line      object
# Unit price       float64
# Quantity           int64
# Date              object
# Time              object
# Payment           object
# Rating           float64
# dtype: object

# %%
dataset.describe()
# Out:
#         Unit price     Quantity      Rating
# count  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000     6.97270
# std      26.494628     2.923431     1.71858
# min      10.080000     1.000000     4.00000
# 25%      32.875000     3.000000     5.50000
# 50%      55.230000     5.000000     7.00000
# 75%      77.935000     8.000000     8.50000
# max      99.960000    10.000000    10.00000

# %%
dataset.isnull().sum()
# Out:
# Invoice ID       0
# Branch           0
# City             0
# Customer type    0
# Gender           0
# Product line     0
# Unit price       0
# Quantity         0
# Date             0
# Time             0
# Payment          0
# Rating           0
# dtype: int64

# %%
# QUESTION 1a
dataset[['Branch']]
# Out:
#     Branch
# 0        A
# 1        C
# 2        A
# 3        A
# 4        A
# ..     ...
# 995      C
# 996      B
# 997      A
# 998      A
# 999      A
#
# [1000 rows x 1 columns]

# %%
dataset["Branch"].replace({"A" : 1, "B" : 2, "C" : 3}, inplace= True)
# Out:
# /var/folders/9c/8yfvcfnx6lqfgkglv0hjr8rr0000gn/T/ipykernel_61469/1443950425.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Branch"].replace({"A" : 1, "B" : 2, "C" : 3}, inplace= True)
# ...

# %%
dataset["Branch"]
# Out:
# 0      1
# 1      3
# 2      1
# 3      1
# 4      1
#       ..
# 995    3
# 996    2
# 997    1
# 998    1
# 999    1
# Name: Branch, Length: 1000, dtype: int64

# %%
dataset.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Date', 'Time', 'Payment',
#        'Rating'],
#       dtype='object')

# %%
# QUESTION 1b

dataset["City"].replace({"Yangon" : 1, "Naypyitaw" : 2, "Mandalay" : 3}, inplace= True)
# Out:
# /var/folders/9c/8yfvcfnx6lqfgkglv0hjr8rr0000gn/T/ipykernel_61469/3394874690.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["City"].replace({"Yangon" : 1, "Naypyitaw" : 2, "Mandalay" : 3}, inplace= True)
# ...

# %%
dataset["City"]
# Out:
# 0      1
# 1      2
# 2      1
# 3      1
# 4      1
#       ..
# 995    2
# 996    3
# 997    1
# 998    1
# 999    1
# Name: City, Length: 1000, dtype: int64

# %%
dataset
# Out:
#       Invoice ID  Branch  City Customer type  Gender            Product line  \
# 0    750-67-8428       1     1        Member  Female       Health and beauty
# 1    226-31-3081       3     2        Normal  Female  Electronic accessories
# 2    631-41-3108       1     1        Normal    Male      Home and lifestyle
# 3    123-19-1176       1     1        Member    Male       Health and beauty
# 4    373-73-7910       1     1        Normal    Male       Sports and travel
# ..           ...     ...   ...           ...     ...                     ...
# 995  233-67-5758       3     2        Normal    Male       Health and beauty
# 996  303-96-2227       2     3        Normal  Female      Home and lifestyle
# 997  727-02-1313       1     1        Member    Male      Food and beverages
# 998  347-56-2442       1     1        Normal    Male      Home and lifestyle
# 999  849-09-3807       1     1        Member  Female     Fashion accessories
#
# ...

# %%
# QUESTION 1c

dataset["Customer type"].replace({"Normal" : 1, "Member" : 2}, inplace= True)
# Out:
# /var/folders/9c/8yfvcfnx6lqfgkglv0hjr8rr0000gn/T/ipykernel_61469/2540739130.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Customer type"].replace({"Normal" : 1, "Member" : 2}, inplace= True)
# ...

# %%
dataset
# Out:
#       Invoice ID  Branch  City  Customer type  Gender            Product line  \
# 0    750-67-8428       1     1              2  Female       Health and beauty
# 1    226-31-3081       3     2              1  Female  Electronic accessories
# 2    631-41-3108       1     1              1    Male      Home and lifestyle
# 3    123-19-1176       1     1              2    Male       Health and beauty
# 4    373-73-7910       1     1              1    Male       Sports and travel
# ..           ...     ...   ...            ...     ...                     ...
# 995  233-67-5758       3     2              1    Male       Health and beauty
# 996  303-96-2227       2     3              1  Female      Home and lifestyle
# 997  727-02-1313       1     1              2    Male      Food and beverages
# 998  347-56-2442       1     1              1    Male      Home and lifestyle
# 999  849-09-3807       1     1              2  Female     Fashion accessories
#
# ...

# %%
# QUESTION 1d

dataset["Product line"]. unique()
# Out:
# array(['Health and beauty', 'Electronic accessories',
#        'Home and lifestyle', 'Sports and travel', 'Food and beverages',
#        'Fashion accessories'], dtype=object)

# %%
dataset["Product line"].replace({"Electronic accessories" : 1, 
                                 "Fashion accessories" : 2,
                                 "Food and beverages" : 3,
                                 "Health and beauty" : 4,
                                 "Home and lifestyle" : 5,
                                 "Sports and travel" : 6},
                                   inplace= True)
# Out:
# /var/folders/9c/8yfvcfnx6lqfgkglv0hjr8rr0000gn/T/ipykernel_61469/2782543949.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Product line"].replace({"Electronic accessories" : 1,
# ...

# %%
dataset
# Out:
#       Invoice ID  Branch  City  Customer type  Gender  Product line  \
# 0    750-67-8428       1     1              2  Female             4
# 1    226-31-3081       3     2              1  Female             1
# 2    631-41-3108       1     1              1    Male             5
# 3    123-19-1176       1     1              2    Male             4
# 4    373-73-7910       1     1              1    Male             6
# ..           ...     ...   ...            ...     ...           ...
# 995  233-67-5758       3     2              1    Male             4
# 996  303-96-2227       2     3              1  Female             5
# 997  727-02-1313       1     1              2    Male             3
# 998  347-56-2442       1     1              1    Male             5
# 999  849-09-3807       1     1              2  Female             2
#
#      Unit price  Quantity       Date   Time      Payment  Rating
# 0         74.69         7   1/5/2019  13:08      Ewallet     9.1
# ...

# %%
# QUESTION 1e

dataset["Payment"].replace({"Cash" : 1, 
                            "Credit card" : 2,
                            "Ewallet" : 3},
                            inplace= True)
# Out:
# /var/folders/9c/8yfvcfnx6lqfgkglv0hjr8rr0000gn/T/ipykernel_61469/405353965.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Payment"].replace({"Cash" : 1,
# ...

# %%
dataset
# Out:
#       Invoice ID  Branch  City  Customer type  Gender  Product line  \
# 0    750-67-8428       1     1              2  Female             4
# 1    226-31-3081       3     2              1  Female             1
# 2    631-41-3108       1     1              1    Male             5
# 3    123-19-1176       1     1              2    Male             4
# 4    373-73-7910       1     1              1    Male             6
# ..           ...     ...   ...            ...     ...           ...
# 995  233-67-5758       3     2              1    Male             4
# 996  303-96-2227       2     3              1  Female             5
# 997  727-02-1313       1     1              2    Male             3
# 998  347-56-2442       1     1              1    Male             5
# 999  849-09-3807       1     1              2  Female             2
#
#      Unit price  Quantity       Date   Time  Payment  Rating
# 0         74.69         7   1/5/2019  13:08        3     9.1
# ...

# %%
# QUESTION 2

dataset["Total"] = dataset["Unit price"] * dataset["Quantity"]
dataset["Tax"] = dataset["Total"] * 0.05
dataset["Final Price"] = dataset["Total"] - dataset["Tax"]

# %%
dataset
# Out:
#       Invoice ID  Branch  City  Customer type  Gender  Product line  \
# 0    750-67-8428       1     1              2  Female             4
# 1    226-31-3081       3     2              1  Female             1
# 2    631-41-3108       1     1              1    Male             5
# 3    123-19-1176       1     1              2    Male             4
# 4    373-73-7910       1     1              1    Male             6
# ..           ...     ...   ...            ...     ...           ...
# 995  233-67-5758       3     2              1    Male             4
# 996  303-96-2227       2     3              1  Female             5
# 997  727-02-1313       1     1              2    Male             3
# 998  347-56-2442       1     1              1    Male             5
# 999  849-09-3807       1     1              2  Female             2
#
#      Unit price  Quantity       Date   Time  Payment  Rating   Total      Tax  \
# ...

# %%
# QUESTION 3

dataset.isnull().sum()
# Out:
# Invoice ID       0
# Branch           0
# City             0
# Customer type    0
# Gender           0
# Product line     0
# Unit price       0
# Quantity         0
# Date             0
# Time             0
# Payment          0
# Rating           0
# Total            0
# Tax              0
# Final Price      0
# dtype: int64

# %%
# QUESTION 4a

dataset.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Date', 'Time', 'Payment',
#        'Rating', 'Total', 'Tax', 'Final Price'],
#       dtype='object')

# %%
produk = dataset.groupby("Product line")["Quantity"].sum()
produk
# Out:
# Product line
# 1    971
# 2    902
# 3    952
# 4    854
# 5    911
# 6    920
# Name: Quantity, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.barplot(x = produk.index, y = produk.values, label = "Quantity", width = 0.4)
plt.legend()
plt.show()

# %%
# QUESTION 4b

normal = dataset.loc[dataset["Customer type"]== 1]
normal_group = normal.groupby("Product line")["Customer type"].count()
normal_group
# Out:
# Product line
# 1    92
# 2    92
# 3    80
# 4    79
# 5    77
# 6    79
# Name: Customer type, dtype: int64

# %%
plt.figure(figsize =(8,5))
sns.barplot(x = normal_group.index, y = normal_group.values, label= "Customer type", width = 0.6)
plt.legend()
plt.show()

# %%
# QUESTION 4c

member = dataset.loc[dataset["Customer type"] == 2]
member_group = member.groupby("Product line")["Customer type"].count()
member_group
# Out:
# Product line
# 1    78
# 2    86
# 3    94
# 4    73
# 5    83
# 6    87
# Name: Customer type, dtype: int64

# %%
plt.figure(figsize =(8,5))
sns.barplot(x = member_group.index, y = member_group.values, label= "Customer type", width = 0.6)
plt.legend()
plt.show()

# %%
# QUESTION 4C

payment = dataset.groupby("Payment")["Invoice ID"].count()
payment
# Out:
# Payment
# 1    344
# 2    311
# 3    345
# Name: Invoice ID, dtype: int64

# %%
plt.figure(figsize =(8,5))
sns.barplot(x = payment.index, y = payment.values, label= "Invoice ID", width = 0.6)
plt.legend()
plt.show()

# %%
# QUESTION 4d

plt.pie(payment.values, labels = payment.index, autopct='%1.1f%%')
plt.title('Payment')
plt.axis('equal')
plt.legend()
plt.show()

# %%
# QUESTION 4e

profit = dataset.groupby("Product line")["Final Price"].sum()

profit
# Out:
# Product line
# 1    49162.5285
# 2    49133.9050
# 3    50797.7160
# 4    44508.6210
# 5    48732.2070
# 6    49873.0335
# Name: Final Price, dtype: float64

# %%
plt.figure(figsize =(8,5))
sns.barplot(x = profit.index, y = profit.values, label= "Final Price", width = 0.6)
plt.legend()
plt.show()

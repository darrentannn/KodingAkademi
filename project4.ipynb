# %% [markdown]
# ASSIGNMENT CROSS ANALYSIS

# %%
import pandas as pd

data = pd.read_csv(r"/Users/darren/Downloads/cvproject/dataset/uber-raw-data-janjune-15.csv")
data
# Out:
#          Dispatching_base_num          Pickup_date Affiliated_base_num  \
# 0                      B02617  2015-05-17 09:47:00              B02617
# 1                      B02617  2015-05-17 09:47:00              B02617
# 2                      B02617  2015-05-17 09:47:00              B02617
# 3                      B02617  2015-05-17 09:47:00              B02774
# 4                      B02617  2015-05-17 09:47:00              B02617
# ...                       ...                  ...                 ...
# 14270474               B02765  2015-05-08 15:43:00              B02765
# 14270475               B02765  2015-05-08 15:43:00              B02765
# 14270476               B02765  2015-05-08 15:43:00              B02765
# 14270477               B02765  2015-05-08 15:44:00              B01899
# 14270478               B02765  2015-05-08 15:44:00              B02682
#
#           locationID
# 0                141
# 1                 65
# 2                100
# 3                 80
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14270479 entries, 0 to 14270478
# Data columns (total 4 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Dispatching_base_num  object
#  1   Pickup_date           object
#  2   Affiliated_base_num   object
#  3   locationID            int64
# dtypes: int64(1), object(3)
# memory usage: 435.5+ MB

# %%
data["Pickup_date"] = pd.to_datetime(data["Pickup_date"])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14270479 entries, 0 to 14270478
# Data columns (total 4 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Dispatching_base_num  object
#  1   Pickup_date           datetime64[ns]
#  2   Affiliated_base_num   object
#  3   locationID            int64
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 435.5+ MB

# %%
# NO 1

data["Pickup_date"].min()
# Out:
# Timestamp('2015-01-01 00:00:05')

# %%
# NO 2

data["Pickup_date"].max()
# Out:
# Timestamp('2015-06-30 23:59:00')

# %%
# NO 3

data["nama_hari"] = data["Pickup_date"].dt.day_name()
data["bulan"] = data["Pickup_date"].dt.month
data["tanggal"] = data["Pickup_date"].dt.day
data["jam"] = data["Pickup_date"].dt.hour
data["menit"] = data["Pickup_date"].dt.minute
data["detik"] = data["Pickup_date"].dt.second

data
# Out:
#          Dispatching_base_num         Pickup_date Affiliated_base_num  \
# 0                      B02617 2015-05-17 09:47:00              B02617
# 1                      B02617 2015-05-17 09:47:00              B02617
# 2                      B02617 2015-05-17 09:47:00              B02617
# 3                      B02617 2015-05-17 09:47:00              B02774
# 4                      B02617 2015-05-17 09:47:00              B02617
# ...                       ...                 ...                 ...
# 14270474               B02765 2015-05-08 15:43:00              B02765
# 14270475               B02765 2015-05-08 15:43:00              B02765
# 14270476               B02765 2015-05-08 15:43:00              B02765
# 14270477               B02765 2015-05-08 15:44:00              B01899
# 14270478               B02765 2015-05-08 15:44:00              B02682
#
#           locationID nama_hari  bulan  tanggal  jam  menit  detik
# ...

# %%
# NO 4

bulan = data.groupby("bulan")["bulan"].count()
bulan
# Out:
# bulan
# 1    1953801
# 2    2263620
# 3    2259773
# 4    2280837
# 5    2695553
# 6    2816895
# Name: bulan, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(x = bulan.index, y = bulan.values)
plt.show()

# %%
# NO 5 

jam = data.groupby("jam")["jam"].count()
jam
# Out:
# jam
# 0      602178
# 1      394510
# 2      260603
# 3      183655
# 4      173038
# 5      193523
# 6      288533
# 7      443543
# 8      583348
# 9      593437
# 10     520092
# 11     516716
# 12     533021
# 13     537909
# 14     584463
# 15     649414
# 16     737170
# 17     863990
# 18     987093
# 19    1007464
# 20     948574
# 21     930462
# 22     922954
# 23     814789
# Name: jam, dtype: int64

# %%
sns.pointplot(x = "nama_hari", y = "tanggal", hue = "jam", data = data)
plt.show()

# %% [markdown]
# ANALISA 2

# %%
data = pd.read_csv("/Users/darren/Downloads/cvproject/dataset/Uber-Jan-Feb-FOIL.csv")
data
# Out:
#     dispatching_base_number       date  active_vehicles  trips
# 0                    B02512   1/1/2015              190   1132
# 1                    B02765   1/1/2015              225   1765
# 2                    B02764   1/1/2015             3427  29421
# 3                    B02682   1/1/2015              945   7679
# 4                    B02617   1/1/2015             1228   9537
# ..                      ...        ...              ...    ...
# 349                  B02764  2/28/2015             3952  39812
# 350                  B02617  2/28/2015             1372  14022
# 351                  B02682  2/28/2015             1386  14472
# 352                  B02512  2/28/2015              230   1803
# 353                  B02765  2/28/2015              747   7753
#
# [354 rows x 4 columns]

# %%
# NO 1

data["dispatching_base_number"].unique()
# Out:
# array(['B02512', 'B02765', 'B02764', 'B02682', 'B02617', 'B02598'],
#       dtype=object)

# %%
data.isnull().sum()
# Out:
# dispatching_base_number    0
# date                       0
# active_vehicles            0
# trips                      0
# dtype: int64

# %%
# NO 2

active = data.groupby("dispatching_base_number")["active_vehicles"].sum()
active.idxmax()
# Out:
# 'B02764'

# %%
sns.boxplot(active)
# Out:
# <Axes: ylabel='active_vehicles'>

# %%
# NO 3 

trips = data.groupby("dispatching_base_number")["trips"].sum()
trips
# Out:
# dispatching_base_number
# B02512      93786
# B02598     540791
# B02617     725025
# B02682     662509
# B02764    1914449
# B02765     193670
# Name: trips, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354 entries, 0 to 353
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   dispatching_base_number  354 non-null    object
#  1   date                     354 non-null    object
#  2   active_vehicles          354 non-null    int64
#  3   trips                    354 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 11.2+ KB

# %%
data["date"] = pd.to_datetime(data["date"])

# %%
rata = data.groupby("date")["trips"].mean()
rata.reset_index()
# Out:
#          date         trips
# 0  2015-01-01   9406.166667
# 1  2015-01-02   6531.500000
# 2  2015-01-03   9741.500000
# 3  2015-01-04   6799.666667
# 4  2015-01-05   7125.333333
# 5  2015-01-06   8737.666667
# 6  2015-01-07  10350.333333
# 7  2015-01-08  11902.166667
# 8  2015-01-09  11716.000000
# 9  2015-01-10  13080.666667
# 10 2015-01-11   9504.333333
# 11 2015-01-12   9607.666667
# 12 2015-01-13  10583.166667
# 13 2015-01-14  10554.833333
# 14 2015-01-15  11121.500000
# 15 2015-01-16  12080.000000
# 16 2015-01-17  12227.166667
# 17 2015-01-18  12078.833333
# 18 2015-01-19   7625.833333
# 19 2015-01-20   9128.666667
# 20 2015-01-21   9857.833333
# 21 2015-01-22  10933.666667
# 22 2015-01-23  11969.833333
# 23 2015-01-24  13451.500000
# 24 2015-01-25   9649.166667
# 25 2015-01-26   7232.500000
# 26 2015-01-27   4207.333333
# 27 2015-01-28  10074.333333
# 28 2015-01-29  11499.000000
# 29 2015-01-30  13953.833333
# 30 2015-01-31  15376.166667
# 31 2015-02-01  12818.333333
# ...
